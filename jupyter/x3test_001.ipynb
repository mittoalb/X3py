# %%
import x3py
from x3py.config import ProInit
from x3py.itkreg import ITKregistration


#Initialize config and register
ref_name = 'test_config.json'
pI = ProInit(ref_name)

extra_args = [ref_name,'TranslationTransform']
itkr = ITKregistration(extra_args, pI.ReturnParameters())


dic = pI.ReturnParameters()
prefix = dic['DataPrefix']
epoints = 20


#ref, paths = getFolderList(prefix,epoints)
#print(ref,paths)

#
itkr.CTREG()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import x3py
#       2 from x3py.config import ProInit
# ----> 3 from x3py.itkreg import ITKregistration
#       6 #Initialize config and register
#       7 ref_name = 'test_config.json'
#
# ModuleNotFoundError: No module named 'x3py.itkreg'
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 329, in _repopulate_pool_static
#     w.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 281, in _Popen
#     return Popen(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 246, in run_regCT
#     x3l.info(file_name, "saved")
# Message: '/local/data/alberto/P-1C_260_recReg.h5'
# Arguments: ('saved',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1423423/923359649.py", line 23, in <module>
#     itkr.CTREG()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 221, in CTREG
#     distribute_jobs(self.run_regCT,enpoints)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/utils.py", line 74, in distribute_jobs
#     with closing(mp.Pool(processes=pool_size)) as p:
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 215, in __init__
#     self._repopulate_pool()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 306, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 329, in _repopulate_pool_static
#     w.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 281, in _Popen
#     return Popen(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 246, in run_regCT
#     x3l.info(file_name, "saved")
# Message: '/local/data/alberto/P-1C_259_recReg.h5'
# Arguments: ('saved',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1423423/923359649.py", line 23, in <module>
#     itkr.CTREG()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 221, in CTREG
#     distribute_jobs(self.run_regCT,enpoints)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/utils.py", line 74, in distribute_jobs
#     with closing(mp.Pool(processes=pool_size)) as p:
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 215, in __init__
#     self._repopulate_pool()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 306, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 329, in _repopulate_pool_static
#     w.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 281, in _Popen
#     return Popen(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 246, in run_regCT
#     x3l.info(file_name, "saved")
# Message: '/local/data/alberto/P-1C_263_recReg.h5'
# Arguments: ('saved',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1423423/923359649.py", line 23, in <module>
#     itkr.CTREG()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 221, in CTREG
#     distribute_jobs(self.run_regCT,enpoints)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/utils.py", line 74, in distribute_jobs
#     with closing(mp.Pool(processes=pool_size)) as p:
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 215, in __init__
#     self._repopulate_pool()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 306, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 329, in _repopulate_pool_static
#     w.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 281, in _Popen
#     return Popen(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 246, in run_regCT
#     x3l.info(file_name, "saved")
# Message: '/local/data/alberto/P-1C_264_recReg.h5'
# Arguments: ('saved',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1423423/923359649.py", line 23, in <module>
#     itkr.CTREG()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 221, in CTREG
#     distribute_jobs(self.run_regCT,enpoints)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/utils.py", line 74, in distribute_jobs
#     with closing(mp.Pool(processes=pool_size)) as p:
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 215, in __init__
#     self._repopulate_pool()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 306, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 329, in _repopulate_pool_static
#     w.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 281, in _Popen
#     return Popen(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 246, in run_regCT
#     x3l.info(file_name, "saved")
# Message: '/local/data/alberto/P-1C_261_recReg.h5'
# Arguments: ('saved',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1423423/923359649.py", line 23, in <module>
#     itkr.CTREG()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 221, in CTREG
#     distribute_jobs(self.run_regCT,enpoints)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/utils.py", line 74, in distribute_jobs
#     with closing(mp.Pool(processes=pool_size)) as p:
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 215, in __init__
#     self._repopulate_pool()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 306, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 329, in _repopulate_pool_static
#     w.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 281, in _Popen
#     return Popen(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 246, in run_regCT
#     x3l.info(file_name, "saved")
# Message: '/local/data/alberto/P-1C_268_recReg.h5'
# Arguments: ('saved',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1423423/923359649.py", line 23, in <module>
#     itkr.CTREG()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 221, in CTREG
#     distribute_jobs(self.run_regCT,enpoints)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/utils.py", line 74, in distribute_jobs
#     with closing(mp.Pool(processes=pool_size)) as p:
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 215, in __init__
#     self._repopulate_pool()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 306, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 329, in _repopulate_pool_static
#     w.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 281, in _Popen
#     return Popen(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 246, in run_regCT
#     x3l.info(file_name, "saved")
# Message: '/local/data/alberto/P-1C_276_recReg.h5'
# Arguments: ('saved',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1423423/923359649.py", line 23, in <module>
#     itkr.CTREG()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 221, in CTREG
#     distribute_jobs(self.run_regCT,enpoints)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/utils.py", line 74, in distribute_jobs
#     with closing(mp.Pool(processes=pool_size)) as p:
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 215, in __init__
#     self._repopulate_pool()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 306, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 329, in _repopulate_pool_static
#     w.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 281, in _Popen
#     return Popen(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 246, in run_regCT
#     x3l.info(file_name, "saved")
# Message: '/local/data/alberto/P-1C_271_recReg.h5'
# Arguments: ('saved',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
# ...
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1423423/923359649.py", line 23, in <module>
#     itkr.CTREG()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 221, in CTREG
#     distribute_jobs(self.run_regCT,enpoints)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/utils.py", line 74, in distribute_jobs
#     with closing(mp.Pool(processes=pool_size)) as p:
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 215, in __init__
#     self._repopulate_pool()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 306, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 329, in _repopulate_pool_static
#     w.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 281, in _Popen
#     return Popen(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 246, in run_regCT
#     x3l.info(file_name, "saved")
# Message: '/local/data/alberto/P-1C_266_recReg.h5'
# Arguments: ('saved',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1423423/923359649.py", line 23, in <module>
#     itkr.CTREG()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 221, in CTREG
#     distribute_jobs(self.run_regCT,enpoints)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/utils.py", line 74, in distribute_jobs
#     with closing(mp.Pool(processes=pool_size)) as p:
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 215, in __init__
#     self._repopulate_pool()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 306, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 329, in _repopulate_pool_static
#     w.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 281, in _Popen
#     return Popen(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 246, in run_regCT
#     x3l.info(file_name, "saved")
# Message: '/local/data/alberto/P-1C_269_recReg.h5'
# Arguments: ('saved',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/logging/__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/traitlets/config/application.py", line 1043, in launch_instance
#     app.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 725, in start
#     self.io_loop.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 513, in dispatch_queue
#     await self.process_one()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 502, in process_one
#     await dispatch(*args)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 409, in dispatch_shell
#     await result
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 729, in execute_request
#     reply_content = await reply_content
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 540, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3009, in run_cell
#     result = self._run_cell(
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3064, in _run_cell
#     result = runner(coro)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3269, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3448, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1423423/923359649.py", line 23, in <module>
#     itkr.CTREG()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 221, in CTREG
#     distribute_jobs(self.run_regCT,enpoints)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/utils.py", line 74, in distribute_jobs
#     with closing(mp.Pool(processes=pool_size)) as p:
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 119, in Pool
#     return Pool(processes, initializer, initargs, maxtasksperchild,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 215, in __init__
#     self._repopulate_pool()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 306, in _repopulate_pool
#     return self._repopulate_pool_static(self._ctx, self.Process,
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 329, in _repopulate_pool_static
#     w.start()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 121, in start
#     self._popen = self._Popen(self)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/context.py", line 281, in _Popen
#     return Popen(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 19, in __init__
#     self._launch(process_obj)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/popen_fork.py", line 71, in _launch
#     code = process_obj._bootstrap(parent_sentinel=child_r)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/home/beams/AMITTONE/miniconda3/envs/x3py/lib/python3.11/site-packages/x3py/itkreg.py", line 246, in run_regCT
#     x3l.info(file_name, "saved")
# Message: '/local/data/alberto/P-1C_270_recReg.h5'
# Arguments: ('saved',)
